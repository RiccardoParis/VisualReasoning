# %%
import os
from google.colab import drive

# 1. Monta Drive
drive.mount('/content/drive')

# 2. Definisci la root del progetto
PROJECT_ROOT = '/content/drive/MyDrive/DeepLearning'
os.makedirs(PROJECT_ROOT, exist_ok=True)
os.chdir(PROJECT_ROOT)

# 3. Crea la struttura cartelle (se non esiste)
folders = ['data', 'notebooks', 'src', 'results']
for folder in folders:
    os.makedirs(folder, exist_ok=True)

print(f"Ambiente pronto in: {os.getcwd()}")
# Out:
# Mounted at /content/drive
# Ambiente pronto in: /content/drive/MyDrive/DeepLearning
